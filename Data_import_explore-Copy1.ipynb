# %%
# Import Dependencies
import pandas as pd
import json
import numpy as np
from pprint import pprint
import re

# %%
# Import the json
file_dir = 'C://Users/Michael/Documents/Data Bootcamp Materials/Repositories/Movies-ETL/Data'
f'{file_dir}/wikipedia-movies.json'
# Out:
# 'C://Users/Michael/Documents/Data Bootcamp Materials/Repositories/Movies-ETL/Data/wikipedia-movies.json'

# %%
# use with to load the json into a variable, then use json.load() to load it into a new variable
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
# check how many records were returned
len(wiki_movies_raw)
# Out:
# 7311

# %%
# examine first five records
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
# ...

# %%
#examine final five records
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
# ...

# %%
# examine a few in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %%
# read kaggle data into pd dataframes
kaggle_metadata_df=pd.read_csv('Data/movies_metadata.csv', low_memory=False)
ratings_df = pd.read_csv('Data/ratings.csv')

# %%
#inspect the kaggle_metadata df
kaggle_metadata_df.head()
kaggle_metadata_df.tail()
kaggle_metadata_df.sample(n=5)
# Out:
#        adult                              belongs_to_collection   budget  \
# 37960  False                                                NaN  4000000
# 42638  False                                                NaN        0
# 16021  False                                                NaN        0
# 43564  False  {'id': 175858, 'name': 'Hidden Collection', 'p...        0
# 4376   False                                                NaN        0
#
#                                                   genres homepage      id  \
# 37960  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN   68016
# 42638                     [{'id': 35, 'name': 'Comedy'}]      NaN  429788
# 16021                                                 []      NaN  135198
# 43564  [{'id': 80, 'name': 'Crime'}, {'id': 27, 'name...      NaN   68163
# 4376   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN   25884
#
#          imdb_id original_language                  original_title  \
# ...

# %%
# inspect the ratings dataframe
ratings_df.head()
ratings_df.tail()
ratings_df.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 8371791    86324     4823     3.5  1318335833
# 11944000  123846    80590     3.0  1291713292
# 20789668  216067      586     3.5  1483064830
# 8788269    90607      292     4.0   945633149
# 3978656    41345    33166     4.5  1190664668

# %%
# attempt to turn the wiki_movies_raw into a df
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
# convert the df columns to a list to be able to see all the column names
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...

# %%
# use list comprehension to create a wiki_movies list with only directors and imbd movies
wiki_movies = [movie for movie in wiki_movies_raw
              if('Director' in movie or 'Directed by' in movie)
              and 'imdb_link' in movie
              and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
# create a wiki_movies_df from the wiki_movies list
wikimovies_df = pd.DataFrame(wiki_movies)
wikimovies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# ...

# %%
#Create the beginnings of cleaning function
def clean_movie(movie):
    movie = dict(movie)
    return movie

# %%
#determine which movies have a value for 'Arabic'
wikimovies_df[wikimovies_df['Arabic'].notnull()]
# Out:
#                                                   url  year  \
# 6834  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 7058   https://en.wikipedia.org/wiki/Capernaum_(film)  2018
#
#                                   imdb_link       title    Directed by  \
# 6834  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7058  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7058                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 6834                                                NaN
# 7058  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 6834                                                NaN      NaN
# 7058  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
# ...

# %%
#find the url of these movies to go and learn more about the language
wikimovies_df[wikimovies_df['Arabic'].notnull()]['url']
# Out:
# 6834    https://en.wikipedia.org/wiki/The_Insult_(film)
# 7058     https://en.wikipedia.org/wiki/Capernaum_(film)
# Name: url, dtype: object

# %%
wikimovies_df[wikimovies_df['Cantonese'].notnull()]['url']
# Out:
# 6456    https://en.wikipedia.org/wiki/Ip_Man_3
# Name: url, dtype: object

# %%
#sort the df columns alphabetically
sorted(wikimovies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cantonese',
#  'Chinese',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'French',
#  'Genre',
#  'Hangul',
#  'Hebrew',
#  'Hepburn',
#  'Japanese',
#  'Label',
#  'Language',
#  'Length',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Picture format',
#  'Polish',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
# ...

# %%
#remove alternative titles key value pairs and add them as one alternative titles dictionary
def clean_movie(movie):
    movie = dict(movie)
    alternate_titles_dict = {}
    alternate_titles_columns = ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']
    for title in alternate_titles_columns:
        if title in movie:
            alternate_titles_dict[title] = movie[title]
            movie.pop(title)
    if len(alternate_titles_dict) > 0:
        movie['Alternate Titles'] = alternate_titles_dict
        
        
    return movie

# %%
# create a clean movies list
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
# create wiki_movies_df from cleaned list
wiki_movies_df = pd.DataFrame(clean_movies)

# %%
# display the columns
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Alternate Titles',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'imdb_link',
# ...

# %%
# create a new function for changing the column names within the clean_movies function
def clean_movie(movie):
    movie = dict(movie)     #to create non-destructive copy
    alternate_titles_dict = {}
    alternate_titles_columns = ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']
    # combine alternate titles into a single list
    for title in alternate_titles_columns:
        if title in movie:
            alternate_titles_dict[title] = movie[title]
            movie.pop(title)
    if len(alternate_titles_dict) > 0:
        movie['Alternate Titles'] = alternate_titles_dict
    # merge column names
    def  change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Directed by', 'Director')
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')    
    return movie

# %%
# create the clean list once again
clean_movies = [clean_movie(movie) for movie in wiki_movies]
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Alternate Titles',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
# extract IMDB ID into a new column in the wiki_movies_df
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')

# %%
#drop duplicate rows in regards to imdb_id column
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
# Out:
# 7076
# 7033

# %%
#find the count of null values in each column of the dataframe
[[column, wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Based on', 4852],
#  ['Starring', 184],
#  ['Narrated by', 6752],
#  ['Cinematography', 691],
#  ['Release date', 32],
#  ['Running time', 139],
#  ['Country', 236],
#  ['Language', 244],
#  ['Budget', 2295],
#  ['Box office', 1548],
#  ['Director', 0],
#  ['Distributor', 357],
#  ['Editor(s)', 548],
#  ['Composer(s)', 518],
#  ['Producer(s)', 202],
#  ['Production company(s)', 1678],
#  ['Writer(s)', 199],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6936],
#  ['Production location(s)', 6986],
#  ['Picture format', 6969],
#  ['Audio format', 6972],
#  ['Voices of', 7031],
#  ['Followed by', 7024],
#  ['Created by', 7023],
#  ['Preceded by', 7023],
#  ['Suggested by', 7032],
#  ['Alternate Titles', 7012],
#  ['Recorded', 7031],
#  ['Venue', 7032],
#  ['Label', 7031],
#  ['Animation by', 7031],
#  ['Color process', 7032],
#  ['imdb_id', 0]]

# %%
# make a list of columns that are less than 90% null values
columns_to_keep = [column for column in wiki_movies_df if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) *.9]

# %%
#update wiki_movies_df to have only the columns to keep
wiki_movies_df = wiki_movies_df[columns_to_keep]

# %%
#identify the data types of the columns
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
# create a series for box office that has no missing values
box_office = wiki_movies_df['Box office'].dropna()

# %%
# create a is_not_a_string function
def is_not_a_string(x):
    return type(x) != str

# %%
# use the previous function to create a series from the box_office series of values that are not string
box_office[box_office.map(is_not_a_string)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# repeat the previous step using a lambda function instead
box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# change the box_office series to not have lists as values
box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)
box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
# Create form_one regular expression variable for box office data
form_one = r"\$\s*\d+\.?\d*\s*[mb]illi?on"

# %%
#count the number of box_office values that match the pattern
box_office.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
# Out:
# 3903

# %%
#create form_two regular expression for box office data
form_two = r"\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illi?on)"

# %%
#count the number of box_office values that match the second pattern
box_office.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
# Out:
# 1559

# %%
#create boolean variables for the matches
matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE, na=False)
#determine which box_office entries do not match either using Pandas logical operators
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 110              $4.35-4.37 million
# 600                      $5000 (US)
# 1070                     35,254,617
# 1480                     £3 million
# 1865                   ¥1.1 billion
# 2032                            N/A
# 2091                           $309
# 2665    926,423 admissions (France)
# 3088      $32 [2] –33.1 million [1]
# 3631                            TBA
# 3859             $38.9–40.3 million
# 3879       CN¥3.650 million (China)
# 4116                     £7,385,434
# 4261             $20.7–23.9 million
# 4306                         $20-30
# 4561        $45.2k (only in Turkey)
# 5447                          £2.56
# 5784                       413 733$
# 6013                        Unknown
# 6145             $17.5–18.4 million
# 6234             $41.8–41.9 million
# 6369                          $111k
# 6370                           $588
# 6593                 less than $372
# 6843                        8 crore
# Name: Box office, dtype: object

# %%
#replace the values given as ranges as just one value
box_office = box_office.str.replace(r'\$.*[-—–](?!a-z)', '$', regex=True)

# %%
# extract the data that matches the forms in the regex
box_office.str.extract(f'({form_one}|{form_two})')
# Out:
#                   0
# 0     $21.4 million
# 1      $2.7 million
# 2       $57,718,089
# 3        $7,331,647
# 4        $6,939,946
# ...             ...
# 7070  $19.4 million
# 7071  $41.9 million
# 7072  $76.1 million
# 7073  $38.4 million
# 7074   $5.5 million
#
# [5485 rows x 1 columns]

# %%
# create function to convert strings to floating point numbers
def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan

    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a million
        value = float(s) * 10**6

        # return value
        return value

    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a billion
        value = float(s) * 10**9

        # return value
        return value

    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):

        # remove dollar sign and commas
        s = re.sub('\$|,','', s)

        # convert to float
        value = float(s)

        # return value
        return value

    # otherwise, return NaN
    else:
        return np.nan

# %%
#parse the numeric data from wiki_movies_df
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
wiki_movies_df['box_office']
# Out:
# 0       21400000.0
# 1        2700000.0
# 2       57718089.0
# 3        7331647.0
# 4        6939946.0
#            ...
# 7071    41900000.0
# 7072    76100000.0
# 7073    38400000.0
# 7074     5500000.0
# 7075           NaN
# Name: box_office, Length: 7033, dtype: float64

# %%
#drop the 'Box office' column as it is no longer needed
wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
# create a budget series
budget = wiki_movies_df['Budget'].dropna()
budget
# Out:
# 0        $20 million
# 1         $6 million
# 2        $35 million
# 3        $12 million
# 4        $25 million
#             ...
# 7070    €4.3 million
# 7071     $42 million
# 7072     $60 million
# 7073     $20 million
# 7074      $9 million
# Name: Budget, Length: 4738, dtype: object

# %%
# convert lists in budget to single strings
budget = budget.apply(lambda x: ' '.join(x) if type(x)==list else x)

# %%
# remove ranges of budgets by removing values between a dollar sign and a hyphen and replacing with $
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
len(budget)
# Out:
# 4738

# %%
# parse budget with the same patterns used before
#create boolean variables for the matches
budget_matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
budget_matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)
#determine which box_office entries do not match either using Pandas logical operators
budget[~budget_matches_form_one & ~budget_matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973             $34 [3] [4] million
# 1126               $120 [4] million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360               $150 [6] million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034              $$200 [4] million
# ...

# %%
# remove citation references: the numbers in square brackets
budget = budget.str.replace(r'\[\d+\]\s*', '', regex=True)
budget[~budget_matches_form_one & ~budget_matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973                     $34 million
# 1126                   $120 million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360                   $150 million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034                  $$200 million
# ...

# %%
#parse the budget values
wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
#drop original budget column
wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %%
# create a variable that holds the non-null values of Release date, convert the lists to strings
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
release_date
# Out:
# 0                            July 11, 1990 ( 1990-07-11 )
# 1       May 17, 1990 ( 1990-05-17 ) (Cannes Film Marke...
# 2                          August 10, 1990 ( 1990-08-10 )
# 3                        December 25, 1990 ( 1990-12-25 )
# 4                                       December 19, 1990
#                               ...
# 7071     December 25, 2018 ( 2018-12-25 ) (United States)
# 7072    December 11, 2018 ( 2018-12-11 ) ( Samuel Gold...
# 7073    November 8, 2018 ( 2018-11-08 ) ( AFI Fest ) D...
# 7074    August 31, 2018 ( 2018-08-31 ) ( Telluride ) D...
# 7075                      28 December 2018 ( 2018-12-28 )
# Name: Release date, Length: 7001, dtype: object

# %%
# create release date forms
releasedate_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)/s/[123]?\d,\s\d{4}'
releasedate_form_two = r'\d{4}.[01]\d.[123]\d'
releasedate_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
releasedate_form_four = r'\d{4}'

# %%
# extract the dates
release_date.str.extract(f'({releasedate_form_one}|{releasedate_form_two}|{releasedate_form_three}|{releasedate_form_four})', flags=re.IGNORECASE)
# Out:
#                   0
# 0              1990
# 1              1990
# 2              1990
# 3              1990
# 4              1990
# ...             ...
# 7071           2018
# 7072           2018
# 7073           2018
# 7074           2018
# 7075  December 2018
#
# [7001 rows x 1 columns]

# %%
#convert to datetimes
wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({releasedate_form_one}|{releasedate_form_two}|{releasedate_form_three}|{releasedate_form_four})', flags=re.IGNORECASE)[0], infer_datetime_format = True)

# %%
# create running time variable from Running time column
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x : ' '.join(x) if type(x) == list else x)

# %%
# determine how many values are in the format ### minutes
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6528

# %%
#determine what the other entries look like
running_time[~running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False)]
# Out:
# 9                                                 102 min
# 26                                                 93 min
# 28                                                32 min.
# 34                                                101 min
# 35                                                 97 min
#                               ...
# 6500       114 minutes [1] 120 minutes (extended edition)
# 6643                                             104 mins
# 6709    90 minutes (theatrical) [1] 91 minutes (unrate...
# 7057    108 minutes (Original cut) 98 minutes (UK cut)...
# 7075                Variable; 90 minutes for default path
# Name: Running time, Length: 366, dtype: object

# %%
#capture the cases where minutes is abbreviated
running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6877

# %%
#whats left
running_time[~running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False)]
# Out:
# 668                     UK:84 min (DVD version) US:86 min
# 727                         78-102 min (depending on cut)
# 840                       Varies (79 [3] –84 [1] minutes)
# 1347                                              25 : 03
# 1443    United States: 77 minutes Argentina: 94 minute...
# 1499                                            1hr 35min
# 1551                                               varies
# 1774                    Netherlands:96 min, Canada:95 min
# 1777                                       approx. 14 min
# 2273                                           1 h 43 min
# 2993                                               1h 48m
# 3925                                              4 hours
# 4425    US domestic version: 86 minutes Original versi...
# 4967    Theatrical cut: 97 minutes Unrated cut: 107 mi...
# 5424                    115 [1] /123 [2] /128 [3] minutes
# 5447                                    1 hour 32 minutes
# ...

# %%
#relax the beginning of the string condition
running_time.str.contains(r'\d*\s*m', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6891

# %%
# extract the run time values
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d*)\s*m')
running_time_extract
# Out:
#         0    1    2
# 0     NaN  NaN  102
# 1     NaN  NaN  114
# 2     NaN  NaN  113
# 3     NaN  NaN  106
# 4     NaN  NaN   95
# ...   ...  ...  ...
# 7071  NaN  NaN   90
# 7072  NaN  NaN  132
# 7073  NaN  NaN  120
# 7074  NaN  NaN  123
# 7075  NaN  NaN   90
#
# [6894 rows x 3 columns]

# %%
# convert to numeric
running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

# %%
# convert the hour minute capture groups to minutes if the minutes capture group is zero
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)

# %%
#drop 'Running time' from the df as well as 'Release date'
wiki_movies_df.drop('Running time', inplace=True, axis=1)

# %%
#drop 'Release date' from the df
wiki_movies_df.drop('Release date', inplace=True, axis=1)

# %%
#take a look at the kaggle data
kaggle_metadata_df.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
# check that all values in 'adult' are true or false
kaggle_metadata_df['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
#isolate the bad data
kaggle_metadata_df[~kaggle_metadata_df['adult'].isin(['True','False'])]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %%
#drop adult column keeping only data where adult column == false
kaggle_metadata_df = kaggle_metadata_df[kaggle_metadata_df['adult'] == 'False'].drop('adult', axis=1)

# %%
# look at the values of the video column
kaggle_metadata_df['video'].value_counts()
# Out:
# False    45358
# True        93
# Name: video, dtype: int64

# %%
# convert the video column to a boolean column 
kaggle_metadata_df['video'] = kaggle_metadata_df['video'] == 'True'

# %%
#convert columns that should be numeric to numeric
kaggle_metadata_df['id'] = pd.to_numeric(kaggle_metadata_df['id'], errors='raise')
kaggle_metadata_df['budget'] = kaggle_metadata_df['budget'].astype(int)
kaggle_metadata_df['popularity'] = pd.to_numeric(kaggle_metadata_df['popularity'], errors='raise')

# %%
#convert release date to datetime
kaggle_metadata_df['release_date'] = pd.to_datetime(kaggle_metadata_df['release_date'])

# %%
#take a look at the ratings df
ratings_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
#convert the timestamp to datetime
ratings_df['timestamp'] = pd.to_datetime(ratings_df['timestamp'], unit='s')

# %%
#create a histogram and describe the ratings['rating'] to determine if there are any glaring errors
pd.options.display.float_format = '{:20,.2f}'.format
ratings_df['rating'].plot(kind='hist')
ratings_df['rating'].describe()
# Out:
# count          26,024,289.00
# mean                    3.53
# std                     1.07
# min                     0.50
# 25%                     3.00
# 50%                     3.50
# 75%                     4.00
# max                     5.00
# Name: rating, dtype: float64

# %%
# merge the wiki and kaggle dfs
movies_df = pd.merge(wiki_movies_df, kaggle_metadata_df, on='imdb_id', suffixes=['_wiki', '_kaggle'])

# %%
movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 6047    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6048    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6049      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6050   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6051  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link                       title_wiki  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# ...

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             drop title_wiki
# running_time             runtime                  keep kaggle, fill in zeroes with wiki
# budget_wiki              budget_kaggle            keep kaggle, fill in zeroes with wiki
# box_office               revenue                  keep kaggle, fill in zeroes with wiki
# release_date_wiki        release_date_kaggle      drop wiki data
# Language                 original_language        drop wiki data
# Production company(s)    production_companies     drop wiki data

# %%
#take a look at titles
movies_df[['title_wiki', 'title_kaggle']]
# Out:
#                            title_wiki                     title_kaggle
# 0     The Adventures of Ford Fairlane  The Adventures of Ford Fairlane
# 1                After Dark, My Sweet             After Dark, My Sweet
# 2                         Air America                      Air America
# 3                               Alice                            Alice
# 4                     Almost an Angel                  Almost an Angel
# ...                               ...                              ...
# 6047                A Fantastic Woman                A Fantastic Woman
# 6048                       Permission                       Permission
# 6049                         Loveless                         Loveless
# 6050                           Gemini                           Gemini
# 6051  How to Talk to Girls at Parties  How to Talk to Girls at Parties
#
# [6052 rows x 2 columns]

# %%
#look at the rows where titles dont match
movies_df[movies_df['title_wiki'] != movies_df['title_kaggle']][['title_wiki', 'title_kaggle']]
# Out:
#                                            title_wiki  \
# 27                                          China Cry
# 36               Daddy's Dyin' ...Who's Got the Will?
# 38                          The Dark Side of the Moon
# 42                                      Delta Force 2
# 48      DuckTales the Movie:Treasure of the Lost Lamp
# ...                                               ...
# 5956                                            Chips
# 5971                                            Spark
# 5994  Pirates of the Caribbean:Dead Men Tell No Tales
# 6023       Valerian and the Cityof a Thousand Planets
# 6028            An Inconvenient Sequel:Truth to Power
#
#                                           title_kaggle
# 27                             China Cry: A True Story
# 36                Daddy's Dyin'... Who's Got the Will?
# 38                           The Dark Side of The Moon
# 42             Delta Force 2: The Colombian Connection
# ...

# %%
#determine if there are missing titles in kaggle data
movies_df[(movies_df['title_kaggle'].isnull())|movies_df['title_kaggle']=='']
# Out:
# Empty DataFrame
# Columns: [url, year, imdb_link, title_wiki, Based on, Starring, Cinematography, Country, Language, Director, Distributor, Editor(s), Composer(s), Producer(s), Production company(s), Writer(s), imdb_id, box_office, budget_wiki, release_date_wiki, running_time, belongs_to_collection, budget_kaggle, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date_kaggle, revenue, runtime, spoken_languages, status, tagline, title_kaggle, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 43 columns]

# %%
# make a scatter plot using runtime and runningtime making sure to fill na with 0 at the same time
movies_df.fillna(0).plot(x='running_time', y='runtime', kind='scatter')
# Out:
# <AxesSubplot:xlabel='running_time', ylabel='runtime'>

# %%
# make a budget scatter plot
movies_df.fillna(0).plot(x='budget_wiki', y='budget_kaggle', kind='scatter')
# Out:
# <AxesSubplot:xlabel='budget_wiki', ylabel='budget_kaggle'>

# %%
# compare box office and revenue columns with a scatter plot
movies_df.fillna(0)[movies_df['box_office']<10**9].plot(x='box_office', y='revenue', kind='scatter')
# Out:
# <AxesSubplot:xlabel='box_office', ylabel='revenue'>

# %%
#compare release dates
movies_df[['release_date_wiki', 'release_date_kaggle']]
# Out:
#      release_date_wiki release_date_kaggle
# 0           1990-01-01          1990-07-11
# 1           1990-01-01          1990-08-24
# 2           1990-01-01          1990-08-10
# 3           1990-01-01          1990-12-25
# 4           1990-01-01          1990-12-21
# ...                ...                 ...
# 6047        2017-02-01          2017-04-06
# 6048        2017-01-01          2017-04-22
# 6049        2017-05-01          2017-06-01
# 6050        2017-01-01          2017-03-12
# 6051        2017-01-01          2017-12-27
#
# [6052 rows x 2 columns]

# %%
#use a line graph with style='.' to compare release_dates
movies_df[['release_date_wiki', 'release_date_kaggle']].plot(x='release_date_wiki', y='release_date_kaggle', style='.')
# Out:
# <AxesSubplot:xlabel='release_date_wiki'>

# %%
#select movies out after 1996 in wiki data and before 1965 in kaggle data
movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')]
# Out:
#                                             url  year  \
# 3607  https://en.wikipedia.org/wiki/The_Holiday  2006
#
#                                    imdb_link   title_wiki Based on  \
# 3607  https://www.imdb.com/title/tt00457939/  The Holiday      NaN
#
#                                                Starring Cinematography  \
# 3607  [Kate Winslet, Cameron Diaz, Jude Law, Jack Bl...    Dean Cundey
#
#             Country Language      Director  ... release_date_kaggle  \
# 3607  United States  English  Nancy Meyers  ...          1953-08-28
#
#                   revenue              runtime  \
# 3607        30,500,000.00               118.00
#
#                               spoken_languages    status  \
# 3607  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 3607  Pouring out of impassioned pages...brawling th...
#
#                title_kaggle  video         vote_average           vote_count
# ...

# %%
# get the index of the row with the bad data
movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index
# Out:
# Int64Index([3607], dtype='int64')

# %%
#drop the bad row
movies_df = movies_df.drop(3607)

# %%
#check for null values
movies_df[movies_df['release_date_wiki'].isnull()]
# Out:
#                                                     url  year  \
# 1008  https://en.wikipedia.org/wiki/Black_Scorpion_(...  1995
# 1061    https://en.wikipedia.org/wiki/Flirt_(1995_film)  1995
# 1121  https://en.wikipedia.org/wiki/Let_It_Be_Me_(19...  1995
# 1564  https://en.wikipedia.org/wiki/A_Brooklyn_State...  1997
# 1633      https://en.wikipedia.org/wiki/Highball_(film)  1997
# 1775        https://en.wikipedia.org/wiki/Velocity_Trap  1997
# 2386  https://en.wikipedia.org/wiki/The_Visit_(2000_...  2000
# 2786   https://en.wikipedia.org/wiki/Stevie_(2002_film)  2002
# 3174  https://en.wikipedia.org/wiki/Return_to_Sender...  2004
# 3651  https://en.wikipedia.org/wiki/Live_Free_or_Die...  2006
# 4967  https://en.wikipedia.org/wiki/For_the_Love_of_...  2012
#
#                                   imdb_link                title_wiki  \
# 1008  https://www.imdb.com/title/tt0112519/            Black Scorpion
# 1061  https://www.imdb.com/title/tt0113080/                     Flirt
# ...

# %%
#set lists in 'Languages to tuples so that value_counts will work on them'
movies_df['Language'].apply(lambda x: tuple(x) if type(x) == list else x).value_counts(dropna=False)
# Out:
# English                        5479
# NaN                             134
# (English, Spanish)               68
# (English, French)                35
# (English, Japanese)              25
#                                ...
# (English /, Zulu)                 1
# (English, Hebrew, Spanish)        1
# (English, Japanese, French)       1
# (English, Spanish, Apache)        1
# Russian                           1
# Name: Language, Length: 198, dtype: int64

# %%
#run value_counts on the kaggle data
movies_df['original_language'].value_counts()
# Out:
# en    5987
# fr      16
# es      10
# it       8
# de       6
# ja       4
# pt       4
# zh       4
# da       2
# hi       2
# sv       1
# ko       1
# ab       1
# tr       1
# he       1
# ar       1
# cn       1
# ru       1
# Name: original_language, dtype: int64

# %%
#take a look at the production companies columns from each dataset
movies_df[['Production company(s)', 'production_companies']]
# Out:
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                           [Fabula, Komplizen Film]
# 6048                           Ball & Chain Productions
# 6049          [Arte France Cinéma, Why Not Productions]
# 6050  [Film Science, Rough House Pictures, Syncopate...
# 6051         [HanWay Films, Little Punk, See-Saw Films]
#
#                                    production_companies
# 0     [{'name': 'Twentieth Century Fox Film Corporat...
# 1     [{'name': 'Avenue Pictures Productions', 'id':...
# 2     [{'name': 'IndieProd Company Productions', 'id...
# 3                [{'name': 'Orion Pictures', 'id': 41}]
# ...

# %%
#drop the wiki columns that won't be used at all
movies_df.drop(columns=['title_wiki', 'release_date_wiki', 'Language', 'Production company(s)'], inplace=True)

# %%
# make a function to fill in missing data for a column pair and then drop the extra column
def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
    for row in df[kaggle_column]:
        if df[kaggle_column][row] == 0:
            df[kaggle_column][row] = df[wiki_column][row]
        
    df.drop(columns=wiki_column, inplace=True)

# %%
fill_missing_kaggle_data(movies_df, 'runtime', 'running_time')

# %%
movies_df['running_time']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'running_time'
#
# The above exception was the direct cause of the following exception:
#
# ...
